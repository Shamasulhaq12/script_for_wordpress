# %%
pip install pandas
pip install requests

# %%
import pandas as pd
import json
import os
import random
import requests
import string


dir_path = os.path.join(os.path.sep,'home','shamas','Desktop/BP TOP 100 Images')

def slug_generator(length=5):
    letters = string.ascii_letters + string.digits
    return ''.join(random.choice(letters) for _ in range(length))


def restImgUL(imgPath):
    url = 'https://swagmygear.com/wp-json/wp/v2/media'
    data = open(imgPath, 'rb').read()
    fileName = os.path.basename(imgPath)
    res = requests.post(url='https://swagmygear.com/wp-json/wp/v2/media',
                        data=data,
                        headers={'Content-Type': 'image/jpg',
                                 'Content-Disposition': 'attachment; filename=%s' % fileName,
                                 'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczovL3N3YWdteWdlYXIuY29tIiwiaWF0IjoxNjg3NDE3MTExLCJuYmYiOjE2ODc0MTcxMTEsImV4cCI6MTY4ODAyMTkxMSwiZGF0YSI6eyJ1c2VyIjp7ImlkIjoiNjAzIn19fQ.K1j-_qlIqWLmU2Bg6Hr-uZ8gfEcnV7dK3XQXjK9qPhk',
                                 },)

    # pp = pprint.PrettyPrinter(indent=4) ## print it pretty.
    # pp.pprint(res.json()) #this is nice when you need it
    newDict = res.json()

    return newDict

   

def add_data_in_json(labels,product_name,image_dic):
    json_data = []
    random_string = slug_generator(length=13)
    
    json_entry = {"fields": [
                {
                    "conditionals": [],
                    "label": "Select (click/unlick) Product Color:",
                    "type": "image-swatch",
                    "id": random_string,
                    "pricing": {"enabled": False, "amount": 0, "type": "fixed"},
                    "clone": {"enabled": False, "type": "qty"},
                    "group": "field",
                    "required": True,
                    "description": "",
                    "class": "",
                    "width": "",
                    "choices": [
                        
                    ],
                    "parent_qty_based": "",
                    "clone_txt": "",
                    "tax": "",
                    "label_pos": "default",
                    "items_per_row": 6,
                    "items_per_row_tablet": 3,
                    "items_per_row_mobile": 3
                }
            ],
                "conditions": [
                {
                    "rules": [
                        {"subject": "product"},
                        {"condition": "product"},
                        {"value": [{"id": 930, "text": ""}]}
                    ]
                }
            ],
                "layout": {
                "swap_type": "last",
                "labels_position": "above",
                "instructions_position": "field",
                "mark_required": True,
                "enable_gallery_images": True,
                "gallery_images": [
                    
                ]
            },
                "variables": []
            }
    slug_list=[]
    for label in labels:
        slug = slug_generator()
        count=labels.index(label)
        slug_list.append(slug)

        json_entry["fields"][0]["choices"].append({
          "selected": False,
          "slug": slug,
          "label": label,
          "pricing_type": "none",
          "pricing_amount": 0,
          "options": {},
          "image": "/wp-content/uploads/"+product_name+"-"+label.replace(" ","-")+".jpg"
        })
        
        
        json_entry["layout"]["gallery_images"].append({
            "source": "upload",
            "url": "/wp-content/uploads/"+product_name+"-"+label.replace(" ","-")+".jpg",
            "id": str(image_dic[label]),
            "values": [
            ]
        })
        print(str(image_dic[label]))
        json_entry["layout"]["gallery_images"][count]["values"].append({
            "field": random_string,
            "value": slug,
            "fieldCache": {
                "label": "Select (click/unlick) Product Color:",
                "choices": [
                    
                ],
                "id":random_string
            }
        })
        
        count-=1
    for i in range(len(labels)):
       
        for lable in labels:
            
            
            json_entry["layout"]["gallery_images"][i]["values"][0]['fieldCache']['choices'].append({
                "value": slug_list[labels.index(lable)],
                "label": lable
            })
            
            


        
        # json_entry["layout"]["gallery_images"][0]["values"][0]['fieldCache']['choices'].append({
        #     "value": slug,
        #     "label": label
        # })
        
            
    
    return json_entry

# print(os.path.normpath(dir_path))
dir_list = os.listdir(dir_path)
df = pd.read_csv('asdf.csv')
df=df.dropna(axis=1, how='all')
df=df.dropna(axis=0, how='all')
d=df['MFG (Hidden)']
check_json = []
product_name = list(df['Prod Name'])
index = 0





for i in d:
    labels = []
    image_dic={}
    product_id = i.split(' ')[1]
    image_id=[]
    if product_id in dir_list:
        product_path = os.path.join(dir_path, product_id)
        
        file_list = os.listdir(product_path)
        
        for file_name in file_list:
           
            original_name = file_name
            image_path = os.path.join(product_path, file_name)
            id = restImgUL(image_path)
            
            split_list = file_name.rsplit("-", 1)  # Split the string from the right with a maximum split count of 1

            if len(split_list) > 1:
                start_index = len(file_name) - len(split_list[1])  # Calculate the start index based on the length of the last split element
                end_index = file_name.find(".", start_index)  # Find the index of "." starting from the calculated start index
                split_string = file_name[start_index:end_index]
                image_dic[split_string] = id['id']
                
                
                labels.append(split_string)
                

        check_json = add_data_in_json(list(set(labels)),product_name[index].replace(' ','-'),image_dic)
        json_string = json.dumps(check_json, indent=4)

        # Write JSON to a file
        with open('json/'+product_name[index]+'.json', 'w') as json_file:
            json_file.write(json_string)
                    
                
                

            
            
    index+=1
# Out:
# 4926
# 4924
# 4923
# 4927
# 4922
# 4928
# 4925
# 4942
# 4938
# 4933
# 4930
# 4941
# 4943
# 4934
# 4944
# 4945
# 4936
# 4931
# 4939
# 4940
# 4935
# 4937
# 4932
# 4929
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 174
#     172 original_name = file_name
#     173 image_path = os.path.join(product_path, file_name)
# --> 174 id = restImgUL(image_path)
#     176 split_list = file_name.rsplit("-", 1)  # Split the string from the right with a maximum split count of 1
#     178 if len(split_list) > 1:
#
# Cell In[18], line 20, in restImgUL(imgPath)
#      18 data = open(imgPath, 'rb').read()
#      19 fileName = os.path.basename(imgPath)
# ---> 20 res = requests.post(url='https://swagmygear.com/wp-json/wp/v2/media',
#      21                     data=data,
#      22                     headers={'Content-Type': 'image/jpg',
#      23                              'Content-Disposition': 'attachment; filename=%s' % fileName,
#      24                              'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczovL3N3YWdteWdlYXIuY29tIiwiaWF0IjoxNjg3NDE3MTExLCJuYmYiOjE2ODc0MTcxMTEsImV4cCI6MTY4ODAyMTkxMSwiZGF0YSI6eyJ1c2VyIjp7ImlkIjoiNjAzIn19fQ.K1j-_qlIqWLmU2Bg6Hr-uZ8gfEcnV7dK3XQXjK9qPhk',
#      25                              },)
#      27 # pp = pprint.PrettyPrinter(indent=4) ## print it pretty.
#      28 # pp.pprint(res.json()) #this is nice when you need it
#      29 newDict = res.json()
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File ~/.pyenv/versions/3.11.3/envs/csv_json/lib/python3.11/site-packages/urllib3/connection.py:402, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     400             self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     401         else:
# --> 402             self.send(chunk)
#     404 # Regardless of whether we have a body or not, if we're in
#     405 # chunked mode we want to send an explicit empty chunk.
#     406 if chunked:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/http/client.py:999, in HTTPConnection.send(self, data)
#     997 sys.audit("http.client.send", self, data)
#     998 try:
# --> 999     self.sock.sendall(data)
#    1000 except TypeError:
#    1001     if isinstance(data, collections.abc.Iterable):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/ssl.py:1241, in SSLSocket.sendall(self, data, flags)
#    1239         amount = len(byte_view)
#    1240         while count < amount:
# -> 1241             v = self.send(byte_view[count:])
#    1242             count += v
#    1243 else:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/ssl.py:1210, in SSLSocket.send(self, data, flags)
#    1206     if flags != 0:
#    1207         raise ValueError(
#    1208             "non-zero flags not allowed in calls to send() on %s" %
#    1209             self.__class__)
# -> 1210     return self._sslobj.write(data)
#    1211 else:
#    1212     return super().send(data, flags)
#
# KeyboardInterrupt:
