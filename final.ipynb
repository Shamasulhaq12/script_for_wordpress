# %%
# pip install pandas
# pip install requests
# Out:
#   Cell In[2], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import json
import os
import random
import requests
import string


dir_path = os.path.join("hit_promo")

def slug_generator(length=5):
    letters = string.ascii_letters + string.digits
    return ''.join(random.choice(letters) for _ in range(length))


def restImgUL(imgPath):
    url = 'https://swagmygear.com/wp-json/wp/v2/media'
    data = open(imgPath, 'rb').read()
    fileName = os.path.basename(imgPath)
    res = requests.post(url='https://swagmygear.com/wp-json/wp/v2/media',
                        data=data,
                        headers={'Content-Type': 'image/jpg',
                                 'Content-Disposition': 'attachment; filename=%s' % fileName,
                                 'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczovL3N3YWdteWdlYXIuY29tIiwiaWF0IjoxNjk0NTk0MjYzLCJuYmYiOjE2OTQ1OTQyNjMsImV4cCI6MTY5NTE5OTA2MywiZGF0YSI6eyJ1c2VyIjp7ImlkIjoiNjAzIn19fQ.WVBopfZ3eEbsROEQi4607kwGO-rH7eFQ_IdUZA-1VF8',
                                 },)

    
    newDict = res.json()

    return newDict

   

def add_data_in_json(labels,product_name,image_dic):
    json_data = []
    random_string = slug_generator(length=13)
    
    json_entry = {"fields": [
                {
                    "conditionals": [],
                    "label": "Select (click/unlick) Product Color:",
                    "type": "image-swatch",
                    "id": random_string,
                    "pricing": {"enabled": False, "amount": 0, "type": "fixed"},
                    "clone": {"enabled": False, "type": "qty"},
                    "group": "field",
                    "required": True,
                    "description": "",
                    "class": "",
                    "width": "",
                    "choices": [
                        
                    ],
                    "parent_qty_based": "",
                    "clone_txt": "",
                    "tax": "",
                    "label_pos": "default",
                    "items_per_row": 6,
                    "items_per_row_tablet": 3,
                    "items_per_row_mobile": 3
                }
            ],
                "conditions": [
                {
                    "rules": [
                        {"subject": "product"},
                        {"condition": "product"},
                        {"value": [{"id": 930, "text": ""}]}
                    ]
                }
            ],
                "layout": {
                "swap_type": "last",
                "labels_position": "above",
                "instructions_position": "field",
                "mark_required": True,
                "enable_gallery_images": True,
                "gallery_images": [
                    
                ]
            },
                "variables": []
            }
    slug_list=[]
    for label in labels:
        slug = slug_generator()
        count=labels.index(label)
        slug_list.append(slug)

        json_entry["fields"][0]["choices"].append({
          "selected": False,
          "slug": slug,
          "label": label,
          "pricing_type": "none",
          "pricing_amount": 0,
          "options": {},
          "image": "/wp-content/uploads/"+product_name+"-"+label.replace(" ","-")+".jpg"
        })
        
        
        
        json_entry["layout"]["gallery_images"].append({
            "source": "upload",
            "url": "/wp-content/uploads/"+product_name+"-"+label.replace(" ","-")+".jpg",
            "id": str(image_dic[label]),
            "values": [
            ]
        })
        
        json_entry["layout"]["gallery_images"][count]["values"].append({
            "field": random_string,
            "value": slug,
            "fieldCache": {
                "label": "Select (click/unlick) Product Color:",
                "choices": [
                    
                ],
                "id":random_string
            }
        })
      
        
        count-=1
    for i in range(len(labels)):
       
        for lable in labels:
     
            
            
            json_entry["layout"]["gallery_images"][i]["values"][0]['fieldCache']['choices'].append({
                "value": slug_list[labels.index(lable)],
                "label": lable
            })
            
            


        
        # json_entry["layout"]["gallery_images"][0]["values"][0]['fieldCache']['choices'].append({
        #     "value": slug,
        #     "label": label
        # })
        
            
    
    return json_entry


dir_list = os.listdir(dir_path)
df = pd.read_csv('Hit-Bags-4-Developer.csv')
df=df.dropna(axis=1, how='all')
df=df.dropna(axis=0, how='all')
# print(df)
d=df[' SKU']

check_json = []
product_name = list(df[' Name'])
index = 0






for i in d:
    labels = []
    image_dic={}
    product_id = i
    image_id=[]
    if product_id in dir_list:
        product_path = os.path.join(dir_path, product_id)
        # print(product_path)
        # print(product_name[index])
        # print(product_path)
        file_list = os.listdir(product_path)
        
        
        for file_name in file_list:
            # print(file_list)
            original_name = file_name
            # # print(type(product_name[index]))
            # file_name = product_name[index].replace(' ','-')
            # file_name = file_name.replace('/','-')
            # # print(file_name)
            
            # rename = file_name.replace(' ','-')
            # rename=rename+"-"+original_name
            # print(rename)
            # os.rename(os.path.join(product_path, original_name), os.path.join(product_path, rename))
           
            original_name = file_name
            image_path = os.path.join(product_path, file_name)
            id = restImgUL(image_path)
            print(id['id'])
            
            
            
            
            split_list = file_name.rsplit("-", 1)  # Split the string from the right with a maximum split count of 1
            if len(split_list) >= 1:
                end_index = file_name.find(".")
                split_string = file_name[0:end_index]
                image_dic[split_string] = id['id']
                labels.append(split_string)
            

        check_json = add_data_in_json(list(set(labels)),product_name[index].replace(' ','-'),image_dic)
        json_string = json.dumps(check_json, indent=4)
        

        # Write JSON to a file
        with open('json/'+product_name[index]+'.json', 'w') as json_file:
            json_file.write(json_string)
                    
                
                

            
            
    index+=1
# Out:
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# inherit
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/bes/Desktop/Data/Beyond Eris Solutions/scripting/Eri Product 2/final.ipynb Cell 2 line 1
# ...
